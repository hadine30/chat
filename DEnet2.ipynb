# %% [markdown]
# <a href="https://colab.research.google.com/github/hadine30/chat/blob/master/DEnet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/liuleiBUAA/DENet.git
# Out:
# Cloning into 'DENet'...
# remote: Enumerating objects: 35, done.
# remote: Total 35 (delta 0), reused 0 (delta 0), pack-reused 35
# Unpacking objects: 100% (35/35), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import files
#files.download("/content/drive/My Drive/datasets_crow/ShanghaiTech_Crowd_Counting_Dataset.zip")

# %%
# !unzip "/content/drive/My Drive/ShanghaiTech_Crowd_Counting_Dataset.zip" -d "/content/"
# Out:
# Archive:  /content/drive/My Drive/ShanghaiTech_Crowd_Counting_Dataset.zip
#    creating: /content/part_A_final/
#    creating: /content/part_A_final/train_data/
#    creating: /content/part_A_final/test_data/
#    creating: /content/part_A_final/train_data/images/
#   inflating: /content/part_A_final/train_data/images/IMG_213.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_212.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_211.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_210.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_21.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_209.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_208.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_207.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_206.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_205.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_204.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_203.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_202.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_201.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_200.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_20.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_2.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_199.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_198.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_197.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_196.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_195.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_194.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_193.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_192.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_191.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_190.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_19.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_189.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_188.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_187.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_186.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_185.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_184.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_183.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_182.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_181.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_180.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_18.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_179.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_178.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_177.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_176.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_175.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_174.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_173.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_172.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_171.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_170.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_17.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_169.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_168.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_167.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_166.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_165.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_164.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_163.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_162.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_161.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_160.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_16.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_159.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_158.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_157.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_156.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_155.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_154.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_153.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_152.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_151.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_150.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_15.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_149.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_148.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_147.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_146.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_145.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_144.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_143.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_142.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_141.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_140.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_14.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_139.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_138.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_137.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_136.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_135.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_134.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_133.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_132.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_131.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_130.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_13.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_129.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_128.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_127.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_126.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_125.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_124.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_123.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_122.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_121.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_120.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_12.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_119.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_118.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_117.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_116.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_115.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_114.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_113.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_112.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_111.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_110.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_11.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_109.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_108.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_107.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_106.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_105.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_104.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_103.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_102.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_101.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_100.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_10.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_1.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_59.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_58.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_57.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_56.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_55.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_54.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_53.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_52.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_51.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_50.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_5.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_49.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_48.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_47.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_46.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_45.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_44.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_43.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_42.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_41.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_40.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_4.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_39.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_38.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_37.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_36.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_35.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_34.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_33.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_32.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_31.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_300.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_30.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_3.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_299.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_298.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_297.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_296.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_295.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_294.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_293.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_292.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_291.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_290.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_29.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_289.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_288.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_287.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_286.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_285.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_284.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_283.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_282.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_281.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_280.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_28.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_279.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_278.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_277.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_276.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_275.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_274.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_273.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_272.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_271.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_270.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_27.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_269.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_268.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_267.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_266.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_265.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_264.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_263.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_262.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_261.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_260.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_26.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_259.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_258.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_257.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_256.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_255.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_254.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_253.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_252.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_251.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_250.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_25.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_249.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_248.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_247.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_246.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_245.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_244.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_243.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_242.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_241.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_240.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_24.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_239.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_238.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_237.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_236.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_235.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_234.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_233.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_232.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_231.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_230.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_23.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_229.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_228.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_227.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_226.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_225.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_224.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_223.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_222.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_221.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_220.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_22.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_219.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_218.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_217.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_216.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_215.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_214.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_99.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_98.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_97.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_96.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_95.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_94.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_93.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_92.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_91.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_90.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_9.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_89.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_88.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_87.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_86.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_85.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_84.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_83.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_82.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_81.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_80.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_8.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_79.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_78.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_77.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_76.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_75.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_74.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_73.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_72.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_71.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_70.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_7.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_69.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_68.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_67.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_66.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_65.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_64.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_63.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_62.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_61.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_60.jpg
#   inflating: /content/part_A_final/train_data/images/IMG_6.jpg
#    creating: /content/part_A_final/train_data/ground_truth/
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_213.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_212.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_211.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_210.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_21.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_209.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_208.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_207.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_206.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_205.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_204.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_203.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_202.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_201.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_200.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_20.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_2.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_199.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_198.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_197.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_196.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_195.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_194.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_193.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_192.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_191.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_190.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_19.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_189.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_188.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_187.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_186.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_185.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_184.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_183.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_182.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_181.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_180.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_18.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_179.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_178.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_177.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_176.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_175.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_174.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_173.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_172.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_171.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_170.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_17.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_169.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_168.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_167.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_166.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_165.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_164.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_163.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_162.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_161.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_160.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_16.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_159.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_158.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_157.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_156.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_155.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_154.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_153.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_152.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_151.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_150.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_15.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_149.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_148.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_147.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_146.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_145.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_144.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_143.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_142.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_141.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_140.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_14.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_139.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_138.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_137.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_136.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_135.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_134.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_133.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_132.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_131.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_130.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_13.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_129.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_128.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_127.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_126.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_125.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_124.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_123.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_122.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_121.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_120.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_12.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_119.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_118.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_117.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_116.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_115.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_114.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_113.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_112.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_111.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_110.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_11.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_109.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_108.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_107.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_106.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_105.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_104.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_103.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_102.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_101.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_100.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_10.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_1.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_59.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_58.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_57.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_56.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_55.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_54.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_53.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_52.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_51.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_50.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_5.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_49.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_48.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_47.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_46.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_45.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_44.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_43.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_42.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_41.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_40.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_4.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_39.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_38.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_37.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_36.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_35.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_34.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_33.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_32.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_31.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_300.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_30.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_3.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_299.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_298.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_297.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_296.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_295.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_294.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_293.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_292.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_291.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_290.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_29.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_289.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_288.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_287.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_286.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_285.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_284.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_283.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_282.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_281.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_280.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_28.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_279.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_278.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_277.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_276.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_275.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_274.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_273.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_272.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_271.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_270.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_27.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_269.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_268.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_267.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_266.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_265.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_264.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_263.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_262.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_261.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_260.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_26.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_259.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_258.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_257.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_256.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_255.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_254.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_253.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_252.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_251.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_250.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_25.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_249.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_248.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_247.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_246.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_245.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_244.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_243.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_242.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_241.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_240.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_24.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_239.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_238.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_237.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_236.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_235.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_234.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_233.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_232.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_231.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_230.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_23.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_229.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_228.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_227.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_226.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_225.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_224.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_223.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_222.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_221.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_220.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_22.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_219.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_218.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_217.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_216.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_215.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_214.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_99.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_98.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_97.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_96.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_95.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_94.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_93.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_92.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_91.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_90.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_9.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_89.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_88.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_87.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_86.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_85.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_84.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_83.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_82.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_81.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_80.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_8.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_79.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_78.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_77.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_76.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_75.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_74.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_73.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_72.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_71.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_70.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_7.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_69.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_68.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_67.mat
#   inflating: /content/part_A_final/train_data/ground_truth/GT_IMG_66.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_65.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_64.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_63.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_62.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_61.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_60.mat
#  extracting: /content/part_A_final/train_data/ground_truth/GT_IMG_6.mat
#    creating: /content/part_A_final/test_data/images/
#   inflating: /content/part_A_final/test_data/images/IMG_5.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_49.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_48.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_47.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_46.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_45.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_44.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_43.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_42.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_41.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_40.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_4.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_39.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_38.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_37.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_36.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_35.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_34.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_33.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_32.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_31.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_30.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_3.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_29.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_28.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_27.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_26.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_25.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_24.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_23.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_22.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_21.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_20.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_2.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_19.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_182.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_181.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_180.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_18.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_179.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_178.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_177.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_176.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_175.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_174.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_173.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_172.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_171.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_170.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_17.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_169.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_168.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_167.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_166.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_165.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_164.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_163.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_162.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_161.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_160.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_16.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_159.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_158.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_157.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_156.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_155.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_154.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_153.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_152.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_151.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_150.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_15.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_149.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_148.jpg
#   inflating: /content/part_A_final/test_data/images/IMG_147.jpg
# ...
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_121.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_120.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_12.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_119.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_118.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_117.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_116.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_115.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_114.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_113.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_112.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_111.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_110.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_11.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_109.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_108.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_107.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_106.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_105.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_104.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_103.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_102.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_101.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_100.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_10.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_1.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_44.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_43.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_42.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_41.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_40.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_4.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_39.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_38.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_37.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_36.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_35.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_34.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_33.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_32.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_316.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_315.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_314.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_313.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_312.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_311.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_310.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_31.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_309.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_308.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_307.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_306.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_305.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_304.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_303.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_302.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_301.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_300.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_30.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_3.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_299.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_298.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_297.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_296.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_295.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_294.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_293.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_292.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_291.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_290.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_29.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_289.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_288.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_287.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_286.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_285.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_284.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_283.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_282.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_281.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_280.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_28.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_279.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_278.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_277.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_276.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_275.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_274.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_273.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_272.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_271.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_270.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_27.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_269.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_268.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_267.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_266.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_265.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_264.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_263.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_262.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_261.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_260.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_26.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_259.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_258.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_257.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_256.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_255.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_254.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_253.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_252.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_251.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_250.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_25.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_249.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_248.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_247.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_246.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_245.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_244.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_243.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_242.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_241.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_240.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_24.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_239.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_238.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_237.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_236.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_235.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_234.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_233.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_232.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_231.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_230.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_23.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_229.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_228.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_227.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_226.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_225.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_224.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_223.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_222.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_221.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_220.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_22.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_219.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_218.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_217.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_216.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_215.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_214.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_99.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_98.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_97.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_96.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_95.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_94.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_93.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_92.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_91.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_90.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_9.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_89.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_88.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_87.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_86.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_85.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_84.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_83.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_82.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_81.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_80.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_8.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_79.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_78.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_77.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_76.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_75.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_74.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_73.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_72.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_71.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_70.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_7.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_69.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_68.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_67.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_66.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_65.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_64.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_63.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_62.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_61.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_60.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_6.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_59.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_58.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_57.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_56.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_55.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_54.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_53.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_52.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_51.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_50.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_5.mat
#   inflating: /content/part_B_final/test_data/ground_truth/GT_IMG_49.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_48.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_47.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_46.mat
#  extracting: /content/part_B_final/test_data/ground_truth/GT_IMG_45.mat

# %%
# !git clone https://github.com/matterport/Mask_RCNN
import os, sys
os.chdir('/content/Mask_RCNN/samples')
# Root directory of the project
ROOT_DIR = os.path.abspath("../")
# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 111.84 MiB | 34.56 MiB/s, done.
# Resolving deltas: 100% (567/567), done.
# Using TensorFlow backend.

# %%
import coco
import mrcnn.model as modellib
ROOT_DIR = os.path.abspath("../")
os.chdir('/content/DENet/')

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt
import json
import coco
import utils
import model as modellib
import visualize
import scipy.io as io
import cv2
# matplotlib inline

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Path to trained weights file
# Download this file and place in the root of your
# project (See README file for details)
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")

class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()

# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)

# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'boos.walk(path)wl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# Load a random image from the images folder
file_names = next(os.walk(IMAGE_DIR))[2]
# file_names=os.listdir(IMAGE_DIR)
# file_names.sort(key= lambda x:int(x[4:-4]))
dict={}

for file_name in file_names:
    # print(type(file_names))
    # image = skimage.io.imread(os.path.join(IMAGE_DIR, random.choice(file_names)))
    image = skimage.io.imread(os.path.join(IMAGE_DIR, file_name),as_grey=False)
    a=len(image.shape)
    if len(image.shape)==2:
        image1=skimage.color.gray2rgb(image)
        image=image1
# Run detection
    results = model.detect([image], verbose=1)

# Visualize results
    r = results[0]
    a=len(r['scores'])
    strname=file_name
    number_of_person=visualize.display_instances(strname, image, r['rois'], r['masks'], r['class_ids'],
                            class_names, r['scores'])
    number = number_of_person
    index = file_name
    dict[index] = int(number)
    os.remove(os.path.join(IMAGE_DIR, file_name))

file=open('trainB.txt','w')
a=json.dump(dict,file)
# file.write(aaa)
file.close()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-8398cb1687af> in <module>()
#      40
#      41 # Create model object in inference mode.
# ---> 42 model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)
#      43
#      44 # Load weights trained on MS-COCO
#
# AttributeError: module 'model' has no attribute 'MaskRCNN'

# %%
#data preparation
import h5py
import scipy.io as io
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter
import scipy
import json
from matplotlib import cm as CM
from image import *
from model import CSRNet
import torch
import cv2

def gaussian_filter_density(gt):
    print (gt.shape)
    density = np.zeros(gt.shape, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(zip(np.nonzero(gt)[1], np.nonzero(gt)[0]))
    leafsize = 2048
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=4)

    print ('generate density...')
    for i, pt in enumerate(pts):
        pt2d = np.zeros(gt.shape, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
    print ('done.')
    return density

root = '/content/'

# part_A_train = os.path.join(root,'Shanghai/newpartA/train_data','images')
# part_A_test = os.path.join(root,'Shanghai/newpartA/test_data','images')
# part_B_train = os.path.join(root,'Shanghai/newpartB/train_data','images')
# part_B_test = os.path.join(root,'Shanghai/newpartB/test_data','images')
part_A_train = os.path.join(root,'part_A_final/train_data/','images')
part_A_test = os.path.join(root,'part_A_final/test_data/','images')
part_B_train = os.path.join(root,'part_B_final/train_data/','images')
part_B_test = os.path.join(root,'part_B_final/test_data/','images')

#part_A_train, part_A_test, part_B_train, part_B_test = [], [], [], []

"""for root, directories, files in os.walk(root):
  if files ="part_A_final":
    for roo, dir, fil in os.walk(root+"/"+files+"/train_data/images"):
      part_A_train = append(fil)
    for roo, dir, fil in os.walk(root+"/"+files+"/test_data/images"):
      part_A_test = append(fil)
  if files ="part_B_final":
    for roo, dir, fil in os.walk(root+"/"+files+"/train_data/images"):
      part_B_train = append(fil)
    for roo, dir, fil in os.walk(root+"/"+files+"/test_data/images"):
      part_B_test = append(fil)"""

for root, directories, files in os.walk("/content/part_B_final"):
  for f in directories:
    print("file",f)

path_sets = [part_B_test]
print(path_sets)
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

for img_path in img_paths:
    print("img path",img_path)
    mask_path = img_path.replace('images', 'images/mask').replace('part_B_final','newpartB')
    print("mask", mask_path)
    mat = io.loadmat(img_path.replace('.jpg', '.mat').replace('images', 'ground_truth').replace('IMG_', 'GT_IMG_'))
    img = cv2.imread(img_path)
    plt.imshow(img)
    mask = cv2.imread(mask_path.replace('.jpg', 'BW.jpg'), 1)
    ret, mask1 = cv2.threshold(mask, 50, 255, cv2.THRESH_BINARY_INV)
    new_img = np.multiply(img, mask1 / 255)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1

    GT = np.sum(k)
    str1 = img_path.split('/images/')
    img_name = str1[1]
    file = open('./detection_result/testB.txt', 'r')
    js = file.read()
    dict = json.loads(js)
    detection = dict[img_name]
    GT_detection = GT - detection

    k = gaussian_filter(k,15)
    new_img = np.multiply(img, mask1 / 255)
    cv2.imwrite(img_path.replace('part_B_final','newpartB'),new_img)
    mask2 = cv2.cvtColor(mask1, cv2.COLOR_BGR2GRAY)

    k1 = np.multiply(k, mask2 / 255)
    target_sum = np.sum(k1)

    k = gaussian_filter(k, 15) * GT_detection / target_sum
    k = np.multiply(k, mask2 / 255)

    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth').replace('part_B_final','newpartB'), 'w') as hf:
            hf['density'] = k
# Out:
# file test_data
# file train_data
# file images
# file ground_truth
# file images
# file ground_truth
# ['/content/part_B_final/test_data/images']
# img path /content/part_B_final/test_data/images/IMG_144.jpg
# mask /content/newpartB/test_data/images/mask/IMG_144.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-074b79118577> in <module>()
#      86     mask = cv2.imread(mask_path.replace('.jpg', 'BW.jpg'), 1)
#      87     ret, mask1 = cv2.threshold(mask, 50, 255, cv2.THRESH_BINARY_INV)
# ---> 88     new_img = np.multiply(img, mask1 / 255)
#      89     k = np.zeros((img.shape[0],img.shape[1]))
#      90     gt = mat["image_info"][0,0][0,0][0]
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
import torch.nn as nn
import torch
from torchvision import models
from utils import save_net,load_net
import torch.nn.functional as F
import resnet
from resnet import conv3x3,BasicBlock,Bottleneck,ResNet

def myconv(in_channels,outchannels,INnorm=True,batch_norm=False,dilation = False):
    if dilation:
        d_rate = 2
    else:
        d_rate = 1
    layers = []
    conv2d = nn.Conv2d(in_channels, outchannels, kernel_size=3, padding=d_rate, dilation=d_rate)
    if INnorm:
        layers += [conv2d, nn.InstanceNorm2d(outchannels), nn.ReLU(inplace=True)]
    elif batch_norm:
        layers += [conv2d, nn.BatchNorm2d(outchannels), nn.ReLU(inplace=True)]
    else:
        layers += [conv2d, nn.ReLU(inplace=True)]
    return nn.Sequential(*layers)

def mydeconv(in_channels,outchannels,INnorm=True,batch_norm=False):
    layers = []
    conv2d = nn.ConvTranspose2d(in_channels, outchannels, kernel_size=3, stride=2, padding=1, output_padding=1)
    if INnorm:
        layers += [conv2d, nn.InstanceNorm2d(outchannels), nn.ReLU(inplace=True)]
    elif batch_norm:
        layers += [conv2d, nn.BatchNorm2d(outchannels), nn.ReLU(inplace=True)]
    else:
        layers += [conv2d, nn.ReLU(inplace=True)]
    return nn.Sequential(*layers)

def my_make_layers(cfg, in_channels = 64,INnorm=True, batch_norm=True,dilation = False):
    if dilation:
        d_rate = 2
    else:
        d_rate = 1
    layers = []
    for v in cfg:
        if v == 'T':
            transconv=nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1)
            if INnorm:
                layers += [transconv, nn.InstanceNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [transconv, nn.ReLU(inplace=True)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=d_rate,dilation = d_rate)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

class CSRNet(nn.Module):
    def __init__(self, load_weights=False):
        super(CSRNet, self).__init__()
        # self.FME=Xception()
        self.seen = 0
        self.frontend_feat = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512]
        self.backend_feat  = [512,512,512,256,128,64]
        # self.dilatedconv1 = myconv(512,256,INnorm=False,batch_norm=True,dilation=True)
        # self.deconv1=mydeconv(256,256,INnorm=False,batch_norm=True)
        # self.dilatedconv2 = myconv(256, 128, INnorm=False, batch_norm=True, dilation=True)
        # self.deconv2 = mydeconv(128, 128, INnorm=False, batch_norm=True)
        # self.dilatedconv3 = myconv(128, 64, INnorm=False, batch_norm=True, dilation=True)
        # self.deconv3 = mydeconv(64, 64, INnorm=False, batch_norm=True)
        # self.dilatedconv4 = myconv(64, 64, INnorm=False, batch_norm=True, dilation=True)
        # self.mydme_feat = [64, 'T', 64]
        self.frontend = make_layers(self.frontend_feat)
        # self.mydme = my_make_layers(self.mydme_feat,in_channels = 64)
        self.backend = make_layers(self.backend_feat,in_channels = 512,dilation = True)
        self.output_layer = nn.Conv2d(64, 1, kernel_size=1)
        if not load_weights:
            mod = models.vgg16(pretrained = True)
            self._initialize_weights()
            for i in xrange(len(self.frontend.state_dict().items())):
                self.frontend.state_dict().items()[i][1].data[:] = mod.state_dict().items()[i][1].data[:]
    def forward(self,x):
        # x = self.FME(x)
        x = self.frontend(x)
        x = self.backend(x)
        # x = self.mydme(x)
        # x = self.dilatedconv1(x)
        # x = self.deconv1(x)
        # x = self.dilatedconv2(x)
        # x = self.deconv2(x)
        # x = self.dilatedconv3(x)
        # x = self.deconv3(x)
        # x = self.dilatedconv4(x)
        x = self.output_layer(x)
        return x
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, std=0.01)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

def make_layers(cfg, in_channels = 3,batch_norm=False,dilation = False):
    if dilation:
        d_rate = 2
    else:
        d_rate = 1
    layers = []
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=d_rate,dilation = d_rate)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

class Conv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, relu=True, same_padding=False, bn=False):
        super(Conv2d, self).__init__()
        padding = int((kernel_size - 1) / 2) if same_padding else 0
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding=padding)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001, momentum=0, affine=True) if bn else None
        self.relu = nn.ReLU(inplace=True) if relu else None

    def forward(self, x):
        x = self.conv(x)
        if self.bn is not None:
            x = self.bn(x)
        if self.relu is not None:
            x = self.relu(x)
        return x

class MCNN(nn.Module):
    '''
    Multi-column CNN
        -Implementation of Single Image Crowd Counting via Multi-column CNN (Zhang et al.)
    '''

    def __init__(self, bn=False):
        super(MCNN, self).__init__()

        self.branch1 = nn.Sequential(Conv2d(3, 16, 9, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(16, 32, 7, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(32, 16, 7, same_padding=True, bn=bn),
                                     Conv2d(16, 8, 7, same_padding=True, bn=bn))

        self.branch2 = nn.Sequential(Conv2d(3, 20, 7, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(20, 40, 5, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(40, 20, 5, same_padding=True, bn=bn),
                                     Conv2d(20, 10, 5, same_padding=True, bn=bn))

        self.branch3 = nn.Sequential(Conv2d(3, 24, 5, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(24, 48, 3, same_padding=True, bn=bn),
                                     nn.MaxPool2d(2),
                                     Conv2d(48, 24, 3, same_padding=True, bn=bn),
                                     Conv2d(24, 12, 3, same_padding=True, bn=bn))

        self.fuse = nn.Sequential(Conv2d(30, 1, 1, same_padding=True, bn=bn))

    def forward(self, im_data):
        x1 = self.branch1(im_data)
        x2 = self.branch2(im_data)
        x3 = self.branch3(im_data)
        x = torch.cat((x1, x2, x3), 1)
        x = self.fuse(x)

        return x

class model(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, relu=True, bn=False, IN= False):
        super(model, self).__init__()
        # padding = int((kernel_size - 1) / 2) if same_padding else 0
        self.conv1 = nn.Conv2d(in_channels, out_channels, 1, stride, padding=0)
        self.conv2 = nn.Conv2d(in_channels, out_channels, 3, stride, padding=1)
        self.conv3 = nn.Conv2d(in_channels, out_channels, 5, stride, padding=2)
        self.conv4 = nn.Conv2d(in_channels, out_channels, 7, stride, padding=3)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001, momentum=0, affine=True) if bn else None
        self.IN = nn.InstanceNorm2d(out_channels,affine=True) if IN else None
        self.relu = nn.ReLU(inplace=True) if relu else None

    def forward(self, x):
        x1 = self.conv1(x)
        x2 = self.conv2(x)
        x3 = self.conv3(x)
        x4 = self.conv4(x)
        x = torch.cat((x1, x2, x3, x4), 1)
        if self.bn is not None:
            x1 = self.bn(x1)
            x2 = self.bn(x2)
            x3 = self.bn(x3)
            x4 = self.bn(x4)
        if self.IN is not None:
            x1 = self.IN(x1)
            x2 = self.IN(x2)
            x3 = self.IN(x3)
            x4 = self.IN(x4)
        if self.relu is not None:
            x1 = self.relu(x1)
            x2 = self.relu(x2)
            x3 = self.relu(x3)
            x4 = self.relu(x4)
        y = torch.cat((x1, x2, x3, x4), 1)
        return y

class SeparableConv2d(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size=1,stride=1,padding=0,dilation=1,bias=False):
        super(SeparableConv2d,self).__init__()

        self.conv1 = nn.Conv2d(in_channels,in_channels,kernel_size,stride,padding,dilation,groups=in_channels,bias=bias)
        self.pointwise = nn.Conv2d(in_channels,out_channels,1,1,0,1,1,bias=bias)

    def forward(self,x):
        x = self.conv1(x)
        x = self.pointwise(x)
        return x

class Block(nn.Module):
    def __init__(self,in_filters,out_filters,reps,strides=1,start_with_relu=True,grow_first=True):
        super(Block, self).__init__()

        if out_filters != in_filters or strides!=1:
            self.skip = nn.Conv2d(in_filters,out_filters,1,stride=strides, bias=False)
            self.skipbn = nn.BatchNorm2d(out_filters)
        else:
            self.skip=None

        self.relu = nn.ReLU(inplace=True)
        rep=[]

        filters=in_filters
        if grow_first:
            rep.append(self.relu)
            rep.append(SeparableConv2d(in_filters,out_filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(out_filters))
            filters = out_filters

        for i in range(reps-1):
            rep.append(self.relu)
            rep.append(SeparableConv2d(filters,filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(filters))

        if not grow_first:
            rep.append(self.relu)
            rep.append(SeparableConv2d(in_filters,out_filters,3,stride=1,padding=1,bias=False))
            rep.append(nn.BatchNorm2d(out_filters))

        if not start_with_relu:
            rep = rep[1:]
        else:
            rep[0] = nn.ReLU(inplace=False)

        if strides != 1:
            rep.append(nn.MaxPool2d(3,strides,1))
        self.rep = nn.Sequential(*rep)

    def forward(self,inp):
        x = self.rep(inp)

        if self.skip is not None:
            skip = self.skip(inp)
            skip = self.skipbn(skip)
        else:
            skip = inp

        x+=skip
        return x

class Xception(nn.Module):
    """
    Xception optimized for the ImageNet dataset, as specified in
    https://arxiv.org/pdf/1610.02357.pdf
    """
    def __init__(self, num_classes=1000):
        """ Constructor
        Args:
            num_classes: number of classes
        """
        super(Xception, self).__init__()
        self.num_classes = num_classes

        self.conv1 = nn.Conv2d(3, 32, 3,2, 0, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(32,64,3,bias=False)
        self.bn2 = nn.BatchNorm2d(64)
        #do relu here

        self.block1=Block(64,128,2,2,start_with_relu=False,grow_first=True)
        self.block2=Block(128,256,3,1,start_with_relu=True,grow_first=True)
        self.block3=Block(256,728,3,1,start_with_relu=True,grow_first=True)

        self.block4=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block5=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block6=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block7=Block(728,728,3,1,start_with_relu=True,grow_first=True)

        self.block8=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block9=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block10=Block(728,728,3,1,start_with_relu=True,grow_first=True)
        self.block11=Block(728,728,2,2,start_with_relu=True,grow_first=True)

        self.block12=Block(728,512,3,1,start_with_relu=True,grow_first=False)

        self.conv3 = SeparableConv2d(512,512,3,1,1)
        self.bn3 = nn.BatchNorm2d(512)

        #do relu here
        self.conv4 = SeparableConv2d(512,512,3,1,1)
        self.bn4 = nn.BatchNorm2d(512)

        self.fc = nn.Linear(2048, num_classes)

        # #------- init weights --------
        # for m in self.modules():
        #     if isinstance(m, nn.Conv2d):
        #         n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
        #         m.weight.data.normal_(0, math.sqrt(2. / n))
        #     elif isinstance(m, nn.BatchNorm2d):
        #         m.weight.data.fill_(1)
        #         m.bias.data.zero_()
        # #-----------------------------

    def features(self, input):
        x = self.conv1(input)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        # x = self.block4(x)
        # x = self.block5(x)
        x = self.block6(x)
        x = self.block7(x)
        # x = self.block8(x)
        # x = self.block9(x)
        # x = self.block10(x)
        x = self.block11(x)
        x = self.block12(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)

        x = self.conv4(x)
        x = self.bn4(x)
        return x

    def logits(self, features):
        x = self.relu(features)

        x = F.adaptive_avg_pool2d(x, (1, 1))
        x = x.view(x.size(0), -1)
        x = self.last_linear(x)
        return x

    def forward(self, input):
        x = self.features(input)
        # x = self.logits(x)
        return x

class SANet(nn.Module):
    def __init__(self):
        super(SANet, self).__init__()
        self.FME=Xception()
        # self.FME = nn.Sequential(model(3, 16, bn=False, IN=True),
        #                        nn.MaxPool2d(2),
        #                        model(64, 32, bn=False, IN=True),
        #                        nn.MaxPool2d(2),
        #                        model(128, 32, bn=False, IN=True),
        #                        nn.MaxPool2d(2),
        #                        model(128, 16, bn=False, IN=True))
        # self.FME = nn.Sequential(model(3, 16, bn=True, IN=False),
        #                          nn.MaxPool2d(2),
        #                          model(64, 32, bn=True, IN=False),
        #                          nn.MaxPool2d(2),
        #                          model(128, 32, bn=True, IN=False),
        #                          nn.MaxPool2d(2),
        #                          model(128, 16, bn=True, IN=False))
        self.DME = nn.Sequential(nn.Conv2d(64, 64, 9, 1, padding=4),
                                 nn.ReLU(inplace=True),
                               nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
                                 nn.ReLU(inplace=True),
                               nn.Conv2d(64, 32, 7, 1, padding=3),
                                 nn.ReLU(inplace=True),
                               nn.ConvTranspose2d(32, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
                                 nn.ReLU(inplace=True),
                               nn.Conv2d(32, 16, 5, 1, padding=2),
                                 nn.ReLU(inplace=True),
                               nn.ConvTranspose2d(16, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
                                 nn.ReLU(inplace=True),
                               nn.Conv2d(16, 16, 3, 1, padding=1),
                                 nn.ReLU(inplace=True),
                               nn.Conv2d(16, 16, 5, 1, padding=2),
                                 nn.ReLU(inplace=True),
                               # nn.Conv2d(16, 16, 3, 1, padding=2, dilation=2),
                               nn.Conv2d(16, 1, 1, 1, padding=0))
        # self.DME = nn.Sequential(nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 32, 7, 1, padding=3),
        #                          nn.ConvTranspose2d(32, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(32, 16, 5, 1, padding=2),
        #                          nn.ConvTranspose2d(16, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(16, 16, 3, 1, padding=1),
        #                          nn.Conv2d(16, 16, 5, 1, padding=2),
        #                          nn.Conv2d(16, 1, 1, 1, padding=0))
        # self.DME = nn.Sequential(nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 64, 7, 1, padding=3),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 64, 5, 1, padding=2),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 64, 3, 1, padding=1),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(64, 16, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(16, 16, 5, 1, padding=2),
        #                          nn.Conv2d(16, 1, 1, 1, padding=0))
        # self.DME = nn.Sequential(nn.Conv2d(64, 64, 9, 1, padding=4),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 64, 7, 1, padding=3),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 64, 5, 1, padding=2),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 64, 3, 1, padding=1),
        #                          nn.Conv2d(64, 64, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(64, 16, 5, 1, padding=2),
        #                          nn.Conv2d(16, 1, 1, 1, padding=0))
        # self.DME = nn.Sequential(nn.Conv2d(64, 64, 9, 1, padding=8, dilation=2),
        #                          nn.ConvTranspose2d(64, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(64, 32, 7, 1, padding=6, dilation=2),
        #                          nn.ConvTranspose2d(32, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(32, 16, 5, 1, padding=4, dilation=2),
        #                          nn.ConvTranspose2d(16, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
        #                          nn.Conv2d(16, 16, 3, 1, padding=2, dilation=2),
        #                          nn.Conv2d(16, 16, 5, 1, padding=4, dilation=2),
        #                          nn.Conv2d(16, 1, 1, 1, padding=0, dilation=2))
    def forward(self, x):
        # x = self.layer1(x)
        # x = self.layer2(x)
        x = self.FME(x)
        x = self.DME(x)
        return x
